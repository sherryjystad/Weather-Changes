# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json


# Import API key
#import api_keys
api_key = "b0879a8fd831712c26e38acaffe8983a"


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    #If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
total_cities = len(cities)
print(total_cities)
# Out:
# 622

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# build data frames
name=[]
lon=[]
lat=[]
cloudiness=[]
country=[]
date=[]
humidity=[]
max_temp=[]
wind_speed=[]
print("Beginning Data Retrieval")
print("-----------------------------")
record=0
#set = 1    
# loop through cities, make API request, and append desired results
for city in cities:
    
    response = requests.get(query_url + city).json()
    #print(json.dumps(response, indent=2, sort_keys=True))
    record = record + 1
    try:
        print(f"Processing Record {record} of {total_cities}  | {city}")
        name.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lon.append(response['coord']['lon'])
        lat.append(response['coord']['lat'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
#        if city == response['name']:
#            set = set + 1
    except (KeyError, IndexError):
        print(f"City not found. Skipping...... {city}.")
        record = record - 1
        
#print("-----------------------------")       
#print("Beginning Retrieval Complete")
#print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of 622  | paka
# Processing Record 2 of 622  | ugoofaaru
# Processing Record 3 of 622  | nanortalik
# Processing Record 4 of 622  | pachino
# Processing Record 5 of 622  | hasaki
# Processing Record 6 of 622  | miraflores
# Processing Record 7 of 622  | portland
# Processing Record 8 of 622  | rumoi
# Processing Record 9 of 622  | khatanga
# Processing Record 10 of 622  | cherskiy
# Processing Record 11 of 622  | palana
# Processing Record 12 of 622  | ca mau
# Processing Record 13 of 622  | talnakh
# Processing Record 14 of 622  | kodiak
# Processing Record 15 of 622  | vichy
# Processing Record 16 of 622  | korla
# City not found. Skipping...... korla.
# Processing Record 16 of 622  | ponta do sol
# Processing Record 17 of 622  | vaini
# Processing Record 18 of 622  | barentsburg
# City not found. Skipping...... barentsburg.
# Processing Record 18 of 622  | taolanaro
# City not found. Skipping...... taolanaro.
# Processing Record 18 of 622  | sechura
# Processing Record 19 of 622  | omboue
# Processing Record 20 of 622  | kavaratti
# Processing Record 21 of 622  | ushuaia
# Processing Record 22 of 622  | makakilo city
# Processing Record 23 of 622  | port elizabeth
# Processing Record 24 of 622  | albany
# Processing Record 25 of 622  | busselton
# Processing Record 26 of 622  | mataura
# Processing Record 27 of 622  | leningradskiy
# Processing Record 28 of 622  | ambanja
# Processing Record 29 of 622  | sitka
# Processing Record 30 of 622  | jamestown
# Processing Record 31 of 622  | tiburon
# Processing Record 32 of 622  | antofagasta
# Processing Record 33 of 622  | torbay
# Processing Record 34 of 622  | srednekolymsk
# Processing Record 35 of 622  | kruisfontein
# Processing Record 36 of 622  | masallatah
# Processing Record 37 of 622  | caravelas
# Processing Record 38 of 622  | bengkulu
# City not found. Skipping...... bengkulu.
# Processing Record 38 of 622  | tsihombe
# City not found. Skipping...... tsihombe.
# Processing Record 38 of 622  | new norfolk
# Processing Record 39 of 622  | bethel
# Processing Record 40 of 622  | rikitea
# Processing Record 41 of 622  | lolua
# City not found. Skipping...... lolua.
# Processing Record 41 of 622  | beringovskiy
# Processing Record 42 of 622  | pozo colorado
# Processing Record 43 of 622  | san quintin
# Processing Record 44 of 622  | yellowknife
# Processing Record 45 of 622  | barrow
# Processing Record 46 of 622  | hermanus
# Processing Record 47 of 622  | zlatoustovsk
# City not found. Skipping...... zlatoustovsk.
# Processing Record 47 of 622  | ulyanovo
# City not found. Skipping...... ulyanovo.
# Processing Record 47 of 622  | bani walid
# Processing Record 48 of 622  | port alfred
# Processing Record 49 of 622  | waupun
# Processing Record 50 of 622  | qaanaaq
# Processing Record 51 of 622  | sao filipe
# Processing Record 52 of 622  | iqaluit
# Processing Record 53 of 622  | sistranda
# Processing Record 54 of 622  | labuhan
# Processing Record 55 of 622  | imbituba
# Processing Record 56 of 622  | mbaiki
# Processing Record 57 of 622  | gillette
# Processing Record 58 of 622  | ribeira grande
# Processing Record 59 of 622  | tranas
# Processing Record 60 of 622  | chagda
# City not found. Skipping...... chagda.
# Processing Record 60 of 622  | jalingo
# Processing Record 61 of 622  | wanaka
# Processing Record 62 of 622  | punta arenas
# Processing Record 63 of 622  | carnarvon
# Processing Record 64 of 622  | atuona
# Processing Record 65 of 622  | sansepolcro
# Processing Record 66 of 622  | isangel
# Processing Record 67 of 622  | kaitangata
# Processing Record 68 of 622  | dikson
# Processing Record 69 of 622  | tautira
# Processing Record 70 of 622  | georgetown
# Processing Record 71 of 622  | luderitz
# Processing Record 72 of 622  | lima
# Processing Record 73 of 622  | kapaa
# Processing Record 74 of 622  | cidreira
# Processing Record 75 of 622  | nikolskoye
# Processing Record 76 of 622  | bambous virieux
# Processing Record 77 of 622  | bossangoa
# Processing Record 78 of 622  | masuguru
# Processing Record 79 of 622  | alyangula
# Processing Record 80 of 622  | upernavik
# Processing Record 81 of 622  | acarau
# City not found. Skipping...... acarau.
# Processing Record 81 of 622  | hobart
# Processing Record 82 of 622  | pacific grove
# Processing Record 83 of 622  | kungurtug
# Processing Record 84 of 622  | shimoda
# Processing Record 85 of 622  | onda
# Processing Record 86 of 622  | kieta
# Processing Record 87 of 622  | lorengau
# Processing Record 88 of 622  | esperance
# Processing Record 89 of 622  | sirohi
# Processing Record 90 of 622  | puerto ayora
# Processing Record 91 of 622  | bentiu
# City not found. Skipping...... bentiu.
# Processing Record 91 of 622  | ilulissat
# Processing Record 92 of 622  | hay river
# Processing Record 93 of 622  | avera
# Processing Record 94 of 622  | pangody
# Processing Record 95 of 622  | tomatlan
# Processing Record 96 of 622  | mount darwin
# Processing Record 97 of 622  | santa maria
# Processing Record 98 of 622  | alice springs
# Processing Record 99 of 622  | heihe
# Processing Record 100 of 622  | ishigaki
# Processing Record 101 of 622  | east london
# Processing Record 102 of 622  | ixtapa
# Processing Record 103 of 622  | casa nova
# Processing Record 104 of 622  | tuktoyaktuk
# Processing Record 105 of 622  | tasiilaq
# Processing Record 106 of 622  | lasa
# Processing Record 107 of 622  | illoqqortoormiut
# City not found. Skipping...... illoqqortoormiut.
# Processing Record 107 of 622  | skelleftea
# Processing Record 108 of 622  | pevek
# Processing Record 109 of 622  | gamba
# Processing Record 110 of 622  | assiniboia
# Processing Record 111 of 622  | naranjal
# Processing Record 112 of 622  | port-gentil
# Processing Record 113 of 622  | klyuchi
# Processing Record 114 of 622  | fortuna
# Processing Record 115 of 622  | cape town
# Processing Record 116 of 622  | avarua
# Processing Record 117 of 622  | los llanos de aridane
# Processing Record 118 of 622  | sioux lookout
# Processing Record 119 of 622  | channarayapatna
# Processing Record 120 of 622  | arraial do cabo
# Processing Record 121 of 622  | longyearbyen
# Processing Record 122 of 622  | provideniya
# Processing Record 123 of 622  | banyuwangi
# Processing Record 124 of 622  | ostrovnoy
# Processing Record 125 of 622  | mahebourg
# Processing Record 126 of 622  | maniitsoq
# Processing Record 127 of 622  | lebu
# Processing Record 128 of 622  | mount gambier
# Processing Record 129 of 622  | butaritari
# Processing Record 130 of 622  | port-cartier
# Processing Record 131 of 622  | puksoozero
# Processing Record 132 of 622  | nemuro
# Processing Record 133 of 622  | te anau
# Processing Record 134 of 622  | tuatapere
# Processing Record 135 of 622  | boali
# Processing Record 136 of 622  | rayagada
# Processing Record 137 of 622  | kununurra
# Processing Record 138 of 622  | coahuayana
# Processing Record 139 of 622  | traverse city
# Processing Record 140 of 622  | kavieng
# Processing Record 141 of 622  | pisco
# Processing Record 142 of 622  | lipin bor
# Processing Record 143 of 622  | victoria
# Processing Record 144 of 622  | troitsko-pechorsk
# Processing Record 145 of 622  | atocha
# Processing Record 146 of 622  | rio grande
# Processing Record 147 of 622  | matara
# Processing Record 148 of 622  | vangaindrano
# Processing Record 149 of 622  | bluff
# Processing Record 150 of 622  | saldanha
# Processing Record 151 of 622  | longonjo
# Processing Record 152 of 622  | jalu
# Processing Record 153 of 622  | belushya guba
# City not found. Skipping...... belushya guba.
# Processing Record 153 of 622  | vanavara
# Processing Record 154 of 622  | saint george
# Processing Record 155 of 622  | hilo
# Processing Record 156 of 622  | sinjah
# City not found. Skipping...... sinjah.
# Processing Record 156 of 622  | baker city
# Processing Record 157 of 622  | goderich
# Processing Record 158 of 622  | yar-sale
# Processing Record 159 of 622  | smolenka
# Processing Record 160 of 622  | emba
# Processing Record 161 of 622  | honiara
# Processing Record 162 of 622  | benguela
# Processing Record 163 of 622  | chokurdakh
# Processing Record 164 of 622  | castro
# Processing Record 165 of 622  | baoqing
# Processing Record 166 of 622  | oranjemund
# Processing Record 167 of 622  | peterhead
# Processing Record 168 of 622  | gizo
# Processing Record 169 of 622  | baghdad
# Processing Record 170 of 622  | nuuk
# Processing Record 171 of 622  | liberty
# Processing Record 172 of 622  | bredasdorp
# Processing Record 173 of 622  | sedelnikovo
# City not found. Skipping...... sedelnikovo.
# Processing Record 173 of 622  | guerrero negro
# Processing Record 174 of 622  | hofn
# Processing Record 175 of 622  | inuvik
# Processing Record 176 of 622  | namibe
# Processing Record 177 of 622  | ninghai
# Processing Record 178 of 622  | clyde river
# Processing Record 179 of 622  | half moon bay
# Processing Record 180 of 622  | virginia beach
# Processing Record 181 of 622  | nefteyugansk
# Processing Record 182 of 622  | mao
# Processing Record 183 of 622  | sangueya
# Processing Record 184 of 622  | saint-philippe
# Processing Record 185 of 622  | vikindu
# Processing Record 186 of 622  | wagar
# Processing Record 187 of 622  | aleksandrovsk-sakhalinskiy
# Processing Record 188 of 622  | port lincoln
# Processing Record 189 of 622  | ancud
# Processing Record 190 of 622  | saskylakh
# Processing Record 191 of 622  | brainerd
# Processing Record 192 of 622  | mataram
# Processing Record 193 of 622  | bijie
# Processing Record 194 of 622  | boyolangu
# Processing Record 195 of 622  | madang
# Processing Record 196 of 622  | ust-tarka
# Processing Record 197 of 622  | petropavlovka
# Processing Record 198 of 622  | eureka
# Processing Record 199 of 622  | seymchan
# Processing Record 200 of 622  | skiros
# City not found. Skipping...... skiros.
# Processing Record 200 of 622  | puerto madryn
# Processing Record 201 of 622  | santa rosa
# Processing Record 202 of 622  | grindavik
# Processing Record 203 of 622  | chuy
# Processing Record 204 of 622  | karasjok
# Processing Record 205 of 622  | nishihara
# Processing Record 206 of 622  | saint combs
# City not found. Skipping...... saint combs.
# Processing Record 206 of 622  | oistins
# Processing Record 207 of 622  | jasper
# Processing Record 208 of 622  | nizhneyansk
# City not found. Skipping...... nizhneyansk.
# Processing Record 208 of 622  | omsukchan
# Processing Record 209 of 622  | rundu
# Processing Record 210 of 622  | bodden town
# Processing Record 211 of 622  | tabou
# Processing Record 212 of 622  | bathsheba
# Processing Record 213 of 622  | broome
# Processing Record 214 of 622  | mabaruma
# Processing Record 215 of 622  | port hardy
# Processing Record 216 of 622  | oranjestad
# Processing Record 217 of 622  | kendari
# Processing Record 218 of 622  | dodola
# Processing Record 219 of 622  | paradwip
# City not found. Skipping...... paradwip.
# Processing Record 219 of 622  | narayanganj
# Processing Record 220 of 622  | karpathos
# Processing Record 221 of 622  | constitucion
# Processing Record 222 of 622  | san patricio
# Processing Record 223 of 622  | mar del plata
# Processing Record 224 of 622  | panguna
# Processing Record 225 of 622  | road town
# Processing Record 226 of 622  | ambulu
# Processing Record 227 of 622  | derzhavinsk
# Processing Record 228 of 622  | pinawa
# Processing Record 229 of 622  | riyadh
# Processing Record 230 of 622  | sinop
# Processing Record 231 of 622  | tidore
# City not found. Skipping...... tidore.
# Processing Record 231 of 622  | fairbanks
# Processing Record 232 of 622  | carlsbad
# Processing Record 233 of 622  | yerbogachen
# Processing Record 234 of 622  | okato
# Processing Record 235 of 622  | mamlyutka
# Processing Record 236 of 622  | sumbawa
# City not found. Skipping...... sumbawa.
# Processing Record 236 of 622  | adrar
# Processing Record 237 of 622  | clarence town
# Processing Record 238 of 622  | mrirt
# City not found. Skipping...... mrirt.
# Processing Record 238 of 622  | slave lake
# Processing Record 239 of 622  | aktash
# City not found. Skipping...... aktash.
# Processing Record 239 of 622  | leh
# Processing Record 240 of 622  | xining
# Processing Record 241 of 622  | severo-kurilsk
# Processing Record 242 of 622  | nantucket
# Processing Record 243 of 622  | weligama
# Processing Record 244 of 622  | tigil
# Processing Record 245 of 622  | goure
# Processing Record 246 of 622  | las vegas
# Processing Record 247 of 622  | inhambane
# Processing Record 248 of 622  | havoysund
# Processing Record 249 of 622  | tiksi
# Processing Record 250 of 622  | vestmannaeyjar
# Processing Record 251 of 622  | salta
# Processing Record 252 of 622  | yeppoon
# Processing Record 253 of 622  | tierralta
# Processing Record 254 of 622  | saint-pierre
# Processing Record 255 of 622  | margate
# Processing Record 256 of 622  | dingle
# Processing Record 257 of 622  | touros
# Processing Record 258 of 622  | axim
# Processing Record 259 of 622  | presidencia roque saenz pena
# Processing Record 260 of 622  | qasigiannguit
# Processing Record 261 of 622  | the valley
# Processing Record 262 of 622  | hithadhoo
# Processing Record 263 of 622  | dombarovskiy
# Processing Record 264 of 622  | lukoyanov
# Processing Record 265 of 622  | nguiu
# City not found. Skipping...... nguiu.
# Processing Record 265 of 622  | cabo san lucas
# Processing Record 266 of 622  | dondukovskaya
# Processing Record 267 of 622  | salalah
# Processing Record 268 of 622  | teknaf
# Processing Record 269 of 622  | sao paulo
# Processing Record 270 of 622  | mersing
# Processing Record 271 of 622  | pochutla
# Processing Record 272 of 622  | ust-kuyga
# Processing Record 273 of 622  | airai
# Processing Record 274 of 622  | puerto colombia
# Processing Record 275 of 622  | casino
# Processing Record 276 of 622  | petushki
# Processing Record 277 of 622  | salinopolis
# Processing Record 278 of 622  | hirara
# Processing Record 279 of 622  | sao joao da barra
# Processing Record 280 of 622  | turukhansk
# Processing Record 281 of 622  | katangli
# Processing Record 282 of 622  | mattru
# Processing Record 283 of 622  | svetlyy
# City not found. Skipping...... svetlyy.
# Processing Record 283 of 622  | saleaula
# City not found. Skipping...... saleaula.
# Processing Record 283 of 622  | dunedin
# Processing Record 284 of 622  | venezuela
# Processing Record 285 of 622  | leticia
# Processing Record 286 of 622  | umzimvubu
# City not found. Skipping...... umzimvubu.
# Processing Record 286 of 622  | waipawa
# Processing Record 287 of 622  | stephenville
# Processing Record 288 of 622  | narsaq
# Processing Record 289 of 622  | ustka
# Processing Record 290 of 622  | alofi
# Processing Record 291 of 622  | lagoa
# Processing Record 292 of 622  | angoche
# Processing Record 293 of 622  | kampong thum
# Processing Record 294 of 622  | faanui
# Processing Record 295 of 622  | taoudenni
# Processing Record 296 of 622  | tiarei
# Processing Record 297 of 622  | balykshi
# City not found. Skipping...... balykshi.
# Processing Record 297 of 622  | ntoum
# Processing Record 298 of 622  | homer
# Processing Record 299 of 622  | vila
# Processing Record 300 of 622  | preston
# Processing Record 301 of 622  | kulhudhuffushi
# Processing Record 302 of 622  | sentyabrskiy
# City not found. Skipping...... sentyabrskiy.
# Processing Record 302 of 622  | durango
# Processing Record 303 of 622  | sento se
# City not found. Skipping...... sento se.
# Processing Record 303 of 622  | rocha
# Processing Record 304 of 622  | byron bay
# Processing Record 305 of 622  | jacareacanga
# Processing Record 306 of 622  | arco
# Processing Record 307 of 622  | djambala
# Processing Record 308 of 622  | puerto morazan
# Processing Record 309 of 622  | bowen
# Processing Record 310 of 622  | sur
# Processing Record 311 of 622  | vredendal
# Processing Record 312 of 622  | padang
# Processing Record 313 of 622  | markivka
# Processing Record 314 of 622  | jurmala
# Processing Record 315 of 622  | mayo
# Processing Record 316 of 622  | jyvaskyla
# City not found. Skipping...... jyvaskyla.
# Processing Record 316 of 622  | husavik
# Processing Record 317 of 622  | vao
# Processing Record 318 of 622  | port macquarie
# Processing Record 319 of 622  | qandala
# Processing Record 320 of 622  | nara
# Processing Record 321 of 622  | hamada
# Processing Record 322 of 622  | jhajjar
# Processing Record 323 of 622  | villeta
# Processing Record 324 of 622  | bargal
# City not found. Skipping...... bargal.
# Processing Record 324 of 622  | pendleton
# Processing Record 325 of 622  | sao felix do xingu
# Processing Record 326 of 622  | gat
# Processing Record 327 of 622  | saint-joseph
# Processing Record 328 of 622  | vardo
# Processing Record 329 of 622  | amderma
# City not found. Skipping...... amderma.
# Processing Record 329 of 622  | palabuhanratu
# City not found. Skipping...... palabuhanratu.
# Processing Record 329 of 622  | jabinyanah
# Processing Record 330 of 622  | northam
# Processing Record 331 of 622  | deputatskiy
# Processing Record 332 of 622  | aksarka
# Processing Record 333 of 622  | san cristobal
# Processing Record 334 of 622  | thompson
# Processing Record 335 of 622  | san ramon
# Processing Record 336 of 622  | pangnirtung
# Processing Record 337 of 622  | suntar
# Processing Record 338 of 622  | fuente de oro
# Processing Record 339 of 622  | grand river south east
# City not found. Skipping...... grand river south east.
# Processing Record 339 of 622  | rock sound
# Processing Record 340 of 622  | bonthe
# Processing Record 341 of 622  | naze
# Processing Record 342 of 622  | srivardhan
# Processing Record 343 of 622  | getulio vargas
# Processing Record 344 of 622  | grand gaube
# Processing Record 345 of 622  | mocuba
# Processing Record 346 of 622  | teguise
# Processing Record 347 of 622  | yulara
# Processing Record 348 of 622  | coruripe
# Processing Record 349 of 622  | huajuapan
# City not found. Skipping...... huajuapan.
# Processing Record 349 of 622  | hokitika
# Processing Record 350 of 622  | rawson
# Processing Record 351 of 622  | batagay-alyta
# Processing Record 352 of 622  | calella
# Processing Record 353 of 622  | lodja
# Processing Record 354 of 622  | qui nhon
# City not found. Skipping...... qui nhon.
# Processing Record 354 of 622  | swellendam
# Processing Record 355 of 622  | benghazi
# Processing Record 356 of 622  | sokolo
# Processing Record 357 of 622  | hun
# Processing Record 358 of 622  | thayetmyo
# Processing Record 359 of 622  | banjar
# Processing Record 360 of 622  | beloha
# Processing Record 361 of 622  | berdigestyakh
# Processing Record 362 of 622  | liverpool
# Processing Record 363 of 622  | ascoli piceno
# Processing Record 364 of 622  | sakakah
# City not found. Skipping...... sakakah.
# Processing Record 364 of 622  | tawkar
# City not found. Skipping...... tawkar.
# Processing Record 364 of 622  | naryan-mar
# Processing Record 365 of 622  | codajas
# Processing Record 366 of 622  | darnah
# Processing Record 367 of 622  | maneadero
# City not found. Skipping...... maneadero.
# Processing Record 367 of 622  | kalachinsk
# Processing Record 368 of 622  | hobyo
# Processing Record 369 of 622  | navoi
# Processing Record 370 of 622  | champasak
# Processing Record 371 of 622  | richards bay
# Processing Record 372 of 622  | tumannyy
# City not found. Skipping...... tumannyy.
# Processing Record 372 of 622  | chara
# Processing Record 373 of 622  | el sauzal
# Processing Record 374 of 622  | north bend
# Processing Record 375 of 622  | williston
# Processing Record 376 of 622  | hadejia
# Processing Record 377 of 622  | starobesheve
# Processing Record 378 of 622  | waverly
# Processing Record 379 of 622  | sayat
# Processing Record 380 of 622  | uruzgan
# Processing Record 381 of 622  | arona
# Processing Record 382 of 622  | waddan
# Processing Record 383 of 622  | coihaique
# Processing Record 384 of 622  | olafsvik
# City not found. Skipping...... olafsvik.
# Processing Record 384 of 622  | neuquen
# Processing Record 385 of 622  | svetlogorsk
# Processing Record 386 of 622  | krymsk
# Processing Record 387 of 622  | ouadda
# Processing Record 388 of 622  | helena
# Processing Record 389 of 622  | lapua
# Processing Record 390 of 622  | sobolevo
# Processing Record 391 of 622  | pishin
# Processing Record 392 of 622  | bababe
# City not found. Skipping...... bababe.
# Processing Record 392 of 622  | klaksvik
# Processing Record 393 of 622  | canalete
# Processing Record 394 of 622  | xiamen
# Processing Record 395 of 622  | los negros
# Processing Record 396 of 622  | tateyama
# Processing Record 397 of 622  | sajanan
# Processing Record 398 of 622  | paamiut
# Processing Record 399 of 622  | wahran
# City not found. Skipping...... wahran.
# Processing Record 399 of 622  | jumla
# Processing Record 400 of 622  | bireun
# Processing Record 401 of 622  | najran
# Processing Record 402 of 622  | ust-kut
# Processing Record 403 of 622  | chegdomyn
# Processing Record 404 of 622  | saint-augustin
# Processing Record 405 of 622  | ucluelet
# Processing Record 406 of 622  | caxito
# Processing Record 407 of 622  | nimaparha
# Processing Record 408 of 622  | komsomolskiy
# Processing Record 409 of 622  | vaitupu
# City not found. Skipping...... vaitupu.
# Processing Record 409 of 622  | labuan
# Processing Record 410 of 622  | mandalgovi
# Processing Record 411 of 622  | brumado
# Processing Record 412 of 622  | grand centre
# City not found. Skipping...... grand centre.
# Processing Record 412 of 622  | russell
# Processing Record 413 of 622  | hailin
# Processing Record 414 of 622  | sehithwa
# Processing Record 415 of 622  | raga
# City not found. Skipping...... raga.
# Processing Record 415 of 622  | piacabucu
# Processing Record 416 of 622  | tilichiki
# Processing Record 417 of 622  | cairns
# Processing Record 418 of 622  | erzin
# Processing Record 419 of 622  | bacalar
# Processing Record 420 of 622  | launceston
# Processing Record 421 of 622  | muromtsevo
# Processing Record 422 of 622  | oksfjord
# Processing Record 423 of 622  | christchurch
# Processing Record 424 of 622  | lerwick
# Processing Record 425 of 622  | acapulco
# Processing Record 426 of 622  | ayan
# Processing Record 427 of 622  | at-bashi
# Processing Record 428 of 622  | bati
# Processing Record 429 of 622  | zhangye
# Processing Record 430 of 622  | ust-kulom
# Processing Record 431 of 622  | bolungarvik
# City not found. Skipping...... bolungarvik.
# Processing Record 431 of 622  | bardiyah
# City not found. Skipping...... bardiyah.
# Processing Record 431 of 622  | tripoli
# Processing Record 432 of 622  | mogadishu
# Processing Record 433 of 622  | namtsy
# Processing Record 434 of 622  | moose factory
# Processing Record 435 of 622  | ruteng
# Processing Record 436 of 622  | port augusta
# Processing Record 437 of 622  | risor
# Processing Record 438 of 622  | buchanan
# Processing Record 439 of 622  | olinda
# Processing Record 440 of 622  | lyuban
# Processing Record 441 of 622  | adre
# Processing Record 442 of 622  | karkaralinsk
# City not found. Skipping...... karkaralinsk.
# Processing Record 442 of 622  | wulanhaote
# City not found. Skipping...... wulanhaote.
# Processing Record 442 of 622  | mys shmidta
# City not found. Skipping...... mys shmidta.
# Processing Record 442 of 622  | tamiahua
# Processing Record 443 of 622  | mogilno
# Processing Record 444 of 622  | tarakan
# Processing Record 445 of 622  | harper
# Processing Record 446 of 622  | shingu
# Processing Record 447 of 622  | gejiu
# Processing Record 448 of 622  | puerto madero
# Processing Record 449 of 622  | miri
# Processing Record 450 of 622  | pokosnoye
# Processing Record 451 of 622  | nabire
# Processing Record 452 of 622  | aswan
# Processing Record 453 of 622  | karratha
# Processing Record 454 of 622  | atbasar
# Processing Record 455 of 622  | samusu
# City not found. Skipping...... samusu.
# Processing Record 455 of 622  | norsup
# Processing Record 456 of 622  | melilla
# Processing Record 457 of 622  | reinach
# Processing Record 458 of 622  | vuktyl
# Processing Record 459 of 622  | ondorhaan
# City not found. Skipping...... ondorhaan.
# Processing Record 459 of 622  | biloela
# Processing Record 460 of 622  | thano bula khan
# City not found. Skipping...... thano bula khan.
# Processing Record 460 of 622  | mehamn
# Processing Record 461 of 622  | bilma
# Processing Record 462 of 622  | gewane
# Processing Record 463 of 622  | bambanglipuro
# Processing Record 464 of 622  | saint-georges
# Processing Record 465 of 622  | elko
# Processing Record 466 of 622  | hazorasp
# Processing Record 467 of 622  | souillac
# Processing Record 468 of 622  | ambilobe
# Processing Record 469 of 622  | pak phanang
# Processing Record 470 of 622  | coos bay
# Processing Record 471 of 622  | sancti spiritus
# Processing Record 472 of 622  | kiruna
# Processing Record 473 of 622  | liberal
# Processing Record 474 of 622  | denpasar
# Processing Record 475 of 622  | barranco
# Processing Record 476 of 622  | osinovo
# Processing Record 477 of 622  | codrington
# Processing Record 478 of 622  | warri
# Processing Record 479 of 622  | pavlodar
# Processing Record 480 of 622  | kropotkin
# Processing Record 481 of 622  | maicao
# Processing Record 482 of 622  | seoul
# Processing Record 483 of 622  | porto velho
# Processing Record 484 of 622  | wukari
# Processing Record 485 of 622  | shrewsbury
# Processing Record 486 of 622  | loralai
# Processing Record 487 of 622  | linchuan
# City not found. Skipping...... linchuan.
# Processing Record 487 of 622  | sao francisco
# Processing Record 488 of 622  | vila velha
# Processing Record 489 of 622  | lefka
# Processing Record 490 of 622  | mount isa
# Processing Record 491 of 622  | jega
# Processing Record 492 of 622  | shar
# Processing Record 493 of 622  | chilca
# Processing Record 494 of 622  | la libertad
# Processing Record 495 of 622  | george
# Processing Record 496 of 622  | daru
# Processing Record 497 of 622  | kupang
# Processing Record 498 of 622  | kralendijk
# Processing Record 499 of 622  | marks
# Processing Record 500 of 622  | cayenne
# Processing Record 501 of 622  | diamantino
# Processing Record 502 of 622  | sokoni
# Processing Record 503 of 622  | farafangana
# Processing Record 504 of 622  | nehe
# Processing Record 505 of 622  | turayf
# Processing Record 506 of 622  | kirakira
# Processing Record 507 of 622  | enshi
# Processing Record 508 of 622  | pouebo
# Processing Record 509 of 622  | maragogi
# Processing Record 510 of 622  | arica
# Processing Record 511 of 622  | azanka
# Processing Record 512 of 622  | cedar city
# Processing Record 513 of 622  | port keats
# Processing Record 514 of 622  | biak
# Processing Record 515 of 622  | prainha
# Processing Record 516 of 622  | safwah
# City not found. Skipping...... safwah.
# Processing Record 516 of 622  | grand-lahou
# Processing Record 517 of 622  | helmstedt
# Processing Record 518 of 622  | nizwa
# Processing Record 519 of 622  | lichuan
# Processing Record 520 of 622  | skagastrond
# City not found. Skipping...... skagastrond.
# Processing Record 520 of 622  | ormond beach
# Processing Record 521 of 622  | ponnani
# Processing Record 522 of 622  | necochea
# Processing Record 523 of 622  | kudahuvadhoo
# Processing Record 524 of 622  | xinyu
# Processing Record 525 of 622  | lerik
# Processing Record 526 of 622  | sao miguel do araguaia
# Processing Record 527 of 622  | boende
# Processing Record 528 of 622  | fuyu
# Processing Record 529 of 622  | jiuquan
# Processing Record 530 of 622  | lompoc
# Processing Record 531 of 622  | les cayes
# Processing Record 532 of 622  | luwuk
# Processing Record 533 of 622  | nagua
# Processing Record 534 of 622  | rivera
# Processing Record 535 of 622  | plettenberg bay
# Processing Record 536 of 622  | bugene
# Processing Record 537 of 622  | mavrodin
# Processing Record 538 of 622  | whitianga
# Processing Record 539 of 622  | lar
# Processing Record 540 of 622  | zlobin
# Processing Record 541 of 622  | muros
# Processing Record 542 of 622  | maumere
# Processing Record 543 of 622  | nouadhibou
# Processing Record 544 of 622  | marsabit
# Processing Record 545 of 622  | quatre cocos
# Processing Record 546 of 622  | tilbury
# Processing Record 547 of 622  | manuk mangkaw
# Processing Record 548 of 622  | esso
# Processing Record 549 of 622  | achisay
# City not found. Skipping...... achisay.
# Processing Record 549 of 622  | ulladulla
# Processing Record 550 of 622  | katsuura
# Processing Record 551 of 622  | thinadhoo
# Processing Record 552 of 622  | olga
# Processing Record 553 of 622  | mamonovo
# Processing Record 554 of 622  | boddam
# Processing Record 555 of 622  | chippewa falls
# Processing Record 556 of 622  | point fortin
# Processing Record 557 of 622  | kidal
# Processing Record 558 of 622  | qaqortoq
# Processing Record 559 of 622  | suruc
# Processing Record 560 of 622  | fare
# Processing Record 561 of 622  | kankon
# Processing Record 562 of 622  | kishtwar
# Processing Record 563 of 622  | rabo de peixe

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dataframe for city information

city_dict = {"City": name, "Cloudiness": cloudiness, "Country": country, "Date": date, "Humidity": humidity,"Lat": lat,
            "Lon": lon,"Max Temp": max_temp,"Wind Speed": wind_speed}
            
city_df = pd.DataFrame(city_dict)
city_df.head()

#save to csv file
city_df.to_csv('output_data/cities.csv')

# %%
city_count = city_df.count()
print(city_count)
# Out:
# City          563
# Cloudiness    563
# Country       563
# Date          563
# Humidity      563
# Lat           563
# Lon           563
# Max Temp      563
# Wind Speed    563
# dtype: int64

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Incorporate the other graph properties
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Max Temp"], marker="o", edgecolors="black")
plt.title("City Latitude vs. Max Temperature 08/22/2018")
plt.ylabel("Max Temperature(F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Calculate Humidity
city_humidity = city_df[('Humidity')]

# Incorporate the other graph properties
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_humidity, marker="o")
plt.title("City Latitude vs. Humidity (08/22/2018)")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Lat_vs_humidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Calculate cloudiness
city_cloudiness = city_df[('Cloudiness')]

# Incorporate the other graph properties
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_cloudiness, marker="o")
plt.title("City Latitude vs. Cloudiness (08/22/2018)")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Lat_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Calculate Wind Speed
city_wind_speed = city_df[('Wind Speed')]

# Incorporate the other graph properties
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_wind_speed, marker="o")
plt.title("City Latitude vs. Wind Speed (08/22/2018)")
plt.ylabel("Wind Speed(mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Lat_vs_Wind Speed.png")

# Show plot
plt.show()
